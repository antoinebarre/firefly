# %% [markdown]
# ## Test de decorator pour checker les types

# %%
import inspect
import numpy as np
import typing
from typing import Tuple, Any
from typing_inspect import get_origin


class ArgChecker:
    """
    | Methods for checking whether arguments passed into a function are of the provided
    | types.
    """

    def enforce_type_hints(self, func):
        """
        | A decorator that ensures arguments passed into a function match the
        | datatypes provided in the type hints.
        |
        | If any dtype is possible for an argument, use typing.Any as the type hint
        |
        | Example
        | -------
        | def add(a: int, b: int):
        |   return a + b
        |
        | Without decorator: add('a', 'b') --> 'ab'  (func has unintended behavior)
        | With decorator:    add('a', 'b') --> AssertionError
        |
        | -------------------------------------------------------------------------
        | Parameters
        | ----------
        |  func
        |    The function being decorated
        |
        |
        | Returns
        | -------
        |  func_w_arg_dtypes_validated
        |    The same function, but throwing an error if inputted dtypes do not
        |    match type hints
        """
        # Get the meta-data from the function
        full_argspec = inspect.getfullargspec(func)

        arg_names = full_argspec.args

        type_hints = full_argspec.annotations
        type_hints = self._make_typings_comparable(type_hints)

        def func_w_arg_dtypes_validated(*args, **kwargs):

            self._check_positional_args(args, arg_names, type_hints)
            self._check_keyword_args(kwargs, type_hints)

            return func(*args, **kwargs)

        # Propagate the original function's name and docstring to decorated function
        func_w_arg_dtypes_validated.__name__ = func.__name__
        func_w_arg_dtypes_validated.__doc__ = func.__doc__
        return func_w_arg_dtypes_validated

    def _make_typings_comparable(self,
                                 types_dict: dict) -> dict:
        """
        | Function argument types cannot be directly compared to objects in Python's
        | built-in typing module because typing objects are special Python classes.
        |
        | For example, type(List[int]) is typing._GenericAlias, but so is:
        |   * type(Dict[str, int])
        |   * type(Union[int, str])
        |   * type(Optional[int])
        |
        | Another problem is that to compare whether a datatype is within the accepted
        | Tuple[*dtypes], Union[*dtypes], or Optional, we must access the dtypes within
        | these objects, as opposed to checking if there is a match with the object
        | itself. (If the type hint is just int, on the other hand, we can compare directly
        | with isinstance(type(arg), int).)
        |
        | This function:
        |    1) Converts typing special classes List, Dict, and Tuple to their generic Python
        |       equivalents
        |    2) Overwrites Union and Optional with the tuples within them
        |    3) Adds np.int64 as a valid dtype if the accepted type is int
        |
        | -----------------------------------------------------------------------------------
        | Parameters
        | ----------
        |  types_dict : dict
        |    Dict of type hints
        |    e.g. {'a': Union[int, str], 'b': Optional[str], 'c': pd.DataFrame}
        |
        |
        | Returns
        | -------
        |  dict
        |    Dict in format for direct comparison
        |    e.g. {'a': (int, np.int64, str), 'b': (str, NoneType), 'c': pd.DataFrame}
        """
        new_dict = types_dict.copy()

        for arg_name in new_dict:

            arg_type = new_dict[arg_name]

            # Convert List -> list, Dict -> dict, Tuple -> tuple
            orig_type = get_origin(arg_type)

            if orig_type in [list, dict, tuple]:
                new_dict[arg_name] = orig_type
                continue

            # Extract info from typing.
            # Union[int, str] -> (int, str), Optional[int] -> (int, NoneType)
            if type(arg_type) == typing._GenericAlias:
                new_dict[arg_name] = arg_type.__args__

                if int in new_dict[arg_name]:
                    new_dict[arg_name] += (np.int64,)

            # Add np.int64 if type is int. int -> (int, np.int64), (int, str) -> (int, np.int64, str)
            if arg_type == int:
                new_dict[arg_name] = (arg_type, np.int64)
            elif isinstance(arg_type, tuple) and int in arg_type:
                new_dict[arg_name] += (np.int64,)

        return new_dict

    def _check_positional_args(self,
                               args: Tuple[Any],
                               arg_names: list,
                               type_hints: dict) -> None:
        """
        | Check whether all argument types in args tuple match argument types in
        | type_hints dict. If type_hints dict has typing.Any, that argument check
        | is skipped. Raises AssertionError if arg dtype and corresponding dtypes
        | in type_hints don't match.
        |
        | -----------------------------------------------------------------------
        | Parameters
        | ----------
        |  args : tuple
        |    Tuple of positional arguments, e.g. (1, 'abc')
        |
        |  arg_names : list
        |    List of argument names, necessary because args is only arg values
        |
        |  type_hints : dict
        |    Dict of type hints, e.g. {'a': (int, float), 'b': str}
        |
        |
        | Returns
        | -------
        |  None
        """
        for i, arg in enumerate(args):

            arg_name = arg_names[i]
            if arg_name == 'self':
                continue

            accepted_types = type_hints[arg_name]
            if accepted_types == typing.Any:
                continue

            assert isinstance(arg, accepted_types), \
                f"arg {arg_name} is type {type(arg)}; doesn't match {accepted_types}"

    def _check_keyword_args(self,
                            kwargs: dict,
                            type_hints: dict) -> None:
        """
        | Check whether all argument types in kwargs dict match argument types in
        | type_hints dict. If type_hints dict has typing.Any, that argument check
        | is skipped. Raises AssertionError if arg dtype and corresponding dtypes
        | in type_hints don't match.
        |
        | -----------------------------------------------------------------------
        | Parameters
        | ----------
        |  kwargs : dict
        |    Dict of keyword arguments, e.g. {'a': 1, 'b': 'abc'}
        |
        | type_hints : dict
        |    Dict of type hints, e.g. {'a': (int, float), 'b': str}
        |
        |
        | Returns
        | -------
        |  None
        """
        # Check keyword args
        for arg_name in kwargs.keys():

            accepted_types = type_hints[arg_name]

            if type_hints[arg_name] == typing.Any:
                continue

            assert isinstance(kwargs[arg_name], accepted_types), \
                f"arg {arg_name} is type {type(kwargs[arg_name])}; doesn't match {accepted_types}"

# %%
from typing import Any, Callable
from beartype import beartype

ac = ArgChecker()

def validate_arguments(func:Callable):
    """Basic function to validate as decorator the arguments type"""
    def validate(*args):
        variables_value_map = dict(zip(func.__code__.co_varnames,args))
        for key, value in func.__annotations__.items():
            print(key,value)
            print(type(value))
            print(func.__name__)
            assert isinstance(variables_value_map[key],value),\
                f'Invalid Attribute for {key}'
        return func(*args)
    return validate

import numpy as np

@beartype
def add2(b:list[str]):
    return True

c = add2([3,1,1])
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[44], line 25
#      21 @beartype
#      22 def add2(b:list[str]):
#      23     return True
# ---> 25 c = add2([3,1,1])
#
# File <@beartype(__main__.add2) at 0x1664f228f40>:31, in add2(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_getrandbits, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.add2() parameter b=[3, 1, 1] violates type hint list[str], as list index 0 item int 3 not instance of str.

# %%
# File: myfile.py

from nptyping import NDArray, Shape
from beartype import beartype

@beartype  # The function signature is now type safe
def fun(df: NDArray[Shape["5, 3"], UInt16]) -> bool: # type: ignore
    return True

a = fun(1)

# %%
from typing import Annotated, Literal, TypeVar
import numpy as np
import numpy.typing as npt


DType = TypeVar("DType", bound=np.generic)

Array4 = Annotated[npt.NDArray[DType], Literal[4]]
Array3x1 = Annotated[npt.NDArray[DType], Literal[3, 1]]

from beartype import beartype

@validate_arguments  # The function signature is now type safe
def fun(df: Array3x1[np.int32]) -> bool: # type: ignore
    return True

a = fun(np.array([1]))
# Out:
# ---------------------------------------------------------------------------
# BeartypeDecorHintPepUnsupportedException  Traceback (most recent call last)
# Cell In[24], line 13
#       9 Array3x1 = Annotated[npt.NDArray[DType], Literal[3, 1]]
#      11 from beartype import beartype
# ---> 13 @beartype  # The function signature is now type safe
#      14 def fun(df: Array3x1) -> bool: # type: ignore
#      15     return True
#      17 a = fun(np.array([1]))
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_cache\cachedecor.py:77, in beartype(obj, conf)
#      62 # Else, "conf" is a configuration.
#      63 #
#      64 # If passed an object to be decorated, this decorator is in decoration
#    (...)
#      74 # here; callers that are doing this are sufficiently intelligent to be
#      75 # trusted to violate PEP 561-compliance if they so choose. So... *shrug*
#      76 elif obj is not None:
# ---> 77     return beartype_object(obj, conf)
#      78 # Else, we were passed *NO* object to be decorated. In this case, this
#      79 # decorator is in configuration rather than decoration mode.
#      80
#    (...)
#      86 # "None" otherwise (i.e., if this is the first call to this public
#      87 # decorator passed this configuration in configuration mode). Phew!
#      88 beartype_confed_cached = _bear_conf_to_decor.get(conf)
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\decorcore.py:97, in beartype_object(obj, conf, **kwargs)
#      61 '''
#      62 Decorate the passed **beartypeable** (i.e., caller-defined object that may
#      63 be decorated by the :func:`beartype.beartype` decorator) with optimal
#    (...)
#      91     Memoized parent decorator wrapping this unmemoized child decorator.
#      92 '''
#      93 # print(f'Decorating object {repr(obj)}...')
#      94
#      95 # Return either...
#      96 return (
# ---> 97     _beartype_object_fatal(obj, conf, **kwargs)
#      98     # If this beartype configuration requests that this decorator raise
#      99     # fatal exceptions at decoration time, defer to the lower-level
#     100     # decorator doing so;
#     101     if conf.warning_cls_on_decorator_exception is None else
#     102     # Else, this beartype configuration requests that this decorator emit
#     103     # fatal warnings at decoration time. In this case, defer to the
#     104     # lower-level decorator doing so.
#     105     _beartype_object_nonfatal(obj, conf, **kwargs)
#     106 )
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\decorcore.py:292, in _beartype_object_fatal(obj, conf, cls_stack)
#     283     return beartype_func_contextlib_contextmanager(  # type: ignore[return-value]
#     284         func=obj,
#     285         conf=conf,
#     286         cls_stack=cls_stack,
#     287     )
#     288 # Else, this function is *NOT* a @contextlib.contextmanager-based isomorphic
#     289 # decorator closure.
#     290
#     291 # Return a new callable decorating that callable with type-checking.
# --> 292 return beartype_func(  # type: ignore[return-value]
#     293     func=obj,
#     294     conf=conf,
#     295     cls_stack=cls_stack,
#     296 )
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_decormore.py:116, in beartype_func(func, conf, **kwargs)
#     113 bear_call.reinit(func, conf, **kwargs)
#     115 # Generate the raw string of Python statements implementing this wrapper.
# --> 116 func_wrapper_code = generate_code(bear_call)
#     118 # If that callable requires *NO* type-checking, silently reduce to a noop
#     119 # and thus the identity decorator by returning that callable as is.
#     120 if not func_wrapper_code:
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_wrap\wrapmain.py:181, in generate_code(bear_call, CODE_RETURN_UNCHECKED_format)
#     175 assert bear_call.__class__ is BeartypeCall, (
#     176     f'{repr(bear_call)} not @beartype call.')
#     178 # Python code snippet type-checking all callable parameters if one or more
#     179 # such parameters are annotated with unignorable type hints *OR* the empty
#     180 # string otherwise.
# --> 181 code_check_params = _code_check_args(bear_call)
#     183 # Python code snippet type-checking the callable return if this return is
#     184 # annotated with an unignorable type hint *OR* the empty string otherwise.
#     185 code_check_return = _code_check_return(bear_call)
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_wrap\wrapmain.py:480, in _code_check_args(bear_call)
#     475     # If any exception was raised, reraise this exception with each
#     476     # placeholder substring (i.e., "EXCEPTION_PLACEHOLDER" instance)
#     477     # replaced by a human-readable description of this callable and
#     478     # annotated parameter.
#     479     except Exception as exception:
# --> 480         reraise_exception_placeholder(
#     481             exception=exception,
#     482             #FIXME: Embed the kind of parameter as well (e.g.,
#     483             #"positional-only", "keyword-only", "variadic positional"),
#     484             #ideally by improving the existing prefix_beartypeable_arg()
#     485             #function to introspect this kind from the callable code object.
#     486             target_str=prefix_beartypeable_arg(
#     487                 func=bear_call.func_wrappee, arg_name=arg_name),
#     488         )
#     490 # If this callable accepts one or more positional type-checked parameters,
#     491 # prefix this code by a snippet localizing the number of these parameters.
#     492 if is_args_positional:
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_util\error\utilerror.py:212, in reraise_exception_placeholder(exception, target_str, source_str)
#     206         exception.args = (exception_message,) + exception.args[1:]
#     207     # Else, this message remains preserved as is.
#     208 # Else, this is an unconventional exception. In this case, preserve this
#     209 # exception as is.
#     210
#     211 # Re-raise this exception while preserving its original traceback.
# --> 212 raise exception.with_traceback(exception.__traceback__)
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_wrap\wrapmain.py:455, in _code_check_args(bear_call)
#     445 cls_stack = (
#     446      bear_call.cls_stack if is_hint_needs_cls_stack(hint) else None)
#     447 # print(f'arg "{arg_name}" hint {repr(hint)} cls_stack: {repr(cls_stack)}')
#     448
#     449 # Generate a memoized parameter-agnostic code snippet type-checking
#     450 # any parameter or return value with an arbitrary name.
#     451 (
#     452     code_param_check_pith,
#     453     func_wrapper_scope,
#     454     hint_forwardrefs_class_basename,
# --> 455 ) = make_func_wrapper_code(hint_sane, bear_call.conf, cls_stack)
#     457 # Merge the local scope required to check this parameter into the
#     458 # local scope currently required by the current wrapper function.
#     459 update_mapping(bear_call.func_wrapper_scope, func_wrapper_scope)
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_util\cache\utilcachecall.py:278, in callable_cached.<locals>._callable_cached(*args)
#     275         args_flat_to_exception[args_flat] = exception
#     277         # Re-raise this exception.
# --> 278         raise exception
#     279 # If one or more objects either passed to *OR* returned from this call
#     280 # are unhashable, perform this call as is *WITHOUT* memoization. While
#     281 # non-ideal, stability is better than raising a fatal exception.
#     282 except TypeError:
#     283     #FIXME: If testing, emit a non-fatal warning or possibly even raise
#     284     #a fatal exception. In either case, we want our test suite to notify
#     285     #us about this.
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_util\cache\utilcachecall.py:270, in callable_cached.<locals>._callable_cached(*args)
#     264 # Else, this callable has yet to be called with these parameters.
#     265
#     266 # Attempt to...
#     267 try:
#     268     # Call this parameter with these parameters and cache the value
#     269     # returned by this call to these parameters.
# --> 270     return_value = args_flat_to_return_value[args_flat] = func(
#     271         *args)
#     272 # If this call raised an exception...
#     273 except Exception as exception:
#     274     # Cache this exception to these parameters.
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_decor\_wrap\_wrapcode.py:86, in make_func_wrapper_code(hint, conf, cls_stack)
#      38 '''
#      39 **Type-checking wrapper function code factory** (i.e., low-level callable
#      40 dynamically generating a pure-Python code snippet type-checking the
#    (...)
#      77     Further details.
#      78 '''
#      80 # Python code snippet comprising a single boolean expression type-checking
#      81 # an arbitrary object against this hint.
#      82 (
#      83     func_wrapper_code_expr,
#      84     func_wrapper_scope,
#      85     hint_forwardrefs_class_basename,
# ---> 86 ) = make_check_expr(hint, conf, cls_stack)
#      88 # Code snippet passing the current class stack if needed to type-check this
#      89 # type hint, defaulting to *NOT* passing this.
#      90 arg_cls_stack = CODE_HINT_ROOT_SUFFIX_CLS_STACK if cls_stack else ''
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_util\cache\utilcachecall.py:278, in callable_cached.<locals>._callable_cached(*args)
#     275         args_flat_to_exception[args_flat] = exception
#     277         # Re-raise this exception.
# --> 278         raise exception
#     279 # If one or more objects either passed to *OR* returned from this call
#     280 # are unhashable, perform this call as is *WITHOUT* memoization. While
#     281 # non-ideal, stability is better than raising a fatal exception.
#     282 except TypeError:
#     283     #FIXME: If testing, emit a non-fatal warning or possibly even raise
#     284     #a fatal exception. In either case, we want our test suite to notify
#     285     #us about this.
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_util\cache\utilcachecall.py:270, in callable_cached.<locals>._callable_cached(*args)
#     264 # Else, this callable has yet to be called with these parameters.
#     265
#     266 # Attempt to...
#     267 try:
#     268     # Call this parameter with these parameters and cache the value
#     269     # returned by this call to these parameters.
# --> 270     return_value = args_flat_to_return_value[args_flat] = func(
#     271         *args)
#     272 # If this call raised an exception...
#     273 except Exception as exception:
#     274     # Cache this exception to these parameters.
#
# File c:\Z\firefly\.venv\Lib\site-packages\beartype\_check\code\codemake.py:1953, in make_check_expr(***failed resolving arguments***)
#    1938             func_curr_code = (
#    1939                 # Strip the erroneous " or" suffix appended by the last
#    1940                 # child hint from this code.
#    (...)
#    1943                 f'{PEP586_CODE_HINT_SUFFIX}'
#    1944             ).format(indent_curr=indent_curr)
#    1945         # Else, this hint is *NOT* a PEP 586-compliant type hint.
#    1946
#    1947         # ............{ UNSUPPORTED                        }............
#    (...)
#    1951         # *NEVER* be triggered. Nonetheless, raise an exception.
#    1952         else:
# -> 1953             raise BeartypeDecorHintPepUnsupportedException(
#    1954                 f'{_EXCEPTION_PREFIX_HINT}'
#    1955                 f'{repr(hint_curr)} unsupported but '
#    1956                 f'erroneously detected as supported as '
#    1957                 f'beartype sign {hint_curr_sign}.'
#    1958             )
#    1960 # ................{ NON-PEP                            }................
#    1961 # Else, this hint is *NOT* PEP-compliant.
#    1962 #
#    (...)
#    1980 #   were the root type hint, it would have already been passed into a
#    1981 #   faster submodule generating PEP-noncompliant code instead.
#    1982 elif isinstance(hint_curr, type):
#    1983     # Code type-checking the current pith against this type.
#
# BeartypeDecorHintPepUnsupportedException: function __main__.fun() parameter "df" type hint numpy.ndarray[typing.Any, numpy.dtype[~DType]] unsupported but erroneously detected as supported as beartype sign "HintSignNumpyArray".

# %%
from beartype import beartype
from beartype.vale import Is
from typing import Annotated
import numpy as np


Int32Array4 = Annotated[np.ndarray, Is[lambda array:
    array.shape == (4,) and np.issubdtype(array.dtype, np.int32)]]
Int32Array3x3 = Annotated[np.ndarray, Is[lambda array:
    array.shape == (3,3) and np.issubdtype(array.dtype, np.int32)]]

import numpy as np
from beartype import beartype


@beartype
def foo(arr: Int32Array4):
    return True

aa = np.array([3.0,1,1,1])
print(aa)
print(type(aa))
print(aa.dtype)

foo(aa)
# Out:
# [3. 1. 1. 1.]
# <class 'numpy.ndarray'>
# float64
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[36], line 25
#      22 print(type(aa))
#      23 print(aa.dtype)
# ---> 25 foo(aa)
#
# File <@beartype(__main__.foo) at 0x1664f192700>:28, in foo(__beartype_func, __beartype_conf, __beartype_get_violation, __beartype_object_1538925339296, __beartype_object_140736689218160, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.foo() parameter arr="array([3., 1., 1., 1.])" violates type hint typing.Annotated[numpy.ndarray, Is[lambda array: array.shape == (4,) and np.issubdtype(array.dtype, np.int32)]], as <protocol "numpy.ndarray"> "array([3., 1., 1., 1.])" violates validator Is[lambda array: array.shape == (4,) and np.issubdtype(array.dtype, np.int32)]:
#     False == Is[lambda array: array.shape == (4,) and np.issubdtype(array.dtype, np.int32)].
